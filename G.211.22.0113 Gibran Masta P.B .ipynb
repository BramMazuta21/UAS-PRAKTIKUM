# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e9024047-efdd-42dd-b8d4-edc0bade2f21" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9024047-efdd-42dd-b8d4-edc0bade2f21">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded

# %%
df=pd.read_csv('stock.csv')
df
# Out:
#                     Stock Name Symbol  Shares Purchase Price  Cost Basis  \
# 0                        Apple   AAPL     100         $90.00   $9,000.00
# 1                    Microsoft   MSFT     200         $32.00   $6,400.00
# 2                   Salesforce    CRM     150         $25.00   $3,750.00
# 3                       Oracle   ORCL     250         $50.00  $12,500.00
# 4   Hewlett Packard Enterprise    HPE     500         $18.00   $9,000.00
# 5                     Alphabet   GOOG     100        $225.00  $22,500.00
# 6                        Intel   INTC     200         $22.00   $4,400.00
# 7                        Cisco   CSCO     225         $18.00   $4,050.00
# 8                     Qualcomm   QCOM     185         $65.00  $12,025.00
# 9                       Amazon   AMZN      50        $800.00  $40,000.00
# 10                      Redhat    RHT     100         $95.00   $9,500.00
# 11                    Facebook     FB    1000         $17.00  $17,000.00
# ...

# %% [markdown]
# 1. A) HISTOGRAM

# %%
plt.figure(figsize=(10,27))


plt.subplot(3,1,1)
plt.title('histogram Purchase Price', pad=20)
plt.grid(linestyle='-.', linewidth=0.7)
plt.hist(df['Purchase Price'], color='yellow')
plt.xlabel('Purchase Price', fontsize=8)
plt.ylabel('Frekuensi', fontsize=8)
plt.xticks(rotation=45)

plt.subplot(3,1,2)
plt.title('histogram Current Price', pad=20)
plt.grid(linestyle='-.', linewidth=0.7)
plt.hist(df['Current Price'], color='orange')
plt.xlabel('Current Price', fontsize=8)
plt.ylabel('Frekuensi', fontsize=8)
plt.xticks(rotation=45)

plt.subplot(3,1,3)
plt.title('histogram Gain/Loss', pad=20)
plt.grid(linestyle='-.', linewidth=0.7)
plt.hist(df['Gain/Loss'], color='brown')
plt.xlabel('Gain/Loss', fontsize=8)
plt.ylabel('Frekuensi', fontsize=8)
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# 1.b Atribut Stock Name dan Symbol yang memiliki Dividen / Share 5 tertinggi

# %%
database1 = df.sort_values(by='Dividend/Share', ascending=False)
dividend = database1.head(5)
dividend
# Out:
#   Stock Name Symbol  Shares Purchase Price  Cost Basis Current Price  \
# 0      Apple   AAPL     100         $90.00   $9,000.00       $144.13
# 8   Qualcomm   QCOM     185         $65.00  $12,025.00        $56.48
# 1  Microsoft   MSFT     200         $32.00   $6,400.00        $65.57
# 7      Cisco   CSCO     225         $18.00   $4,050.00        $33.24
# 6      Intel   INTC     200         $22.00   $4,400.00        $36.07
#
#   Market Value   Gain/Loss Dividend/Share Annual Yield
# 0   $14,413.27  $14,269.14          $2.28         1.58%
# 8   $10,447.88  $10,391.40          $2.12         3.75%
# 1   $13,114.14  $13,048.57          $1.56         2.38%
# 7    $7,478.78   $7,445.54          $1.16         3.49%
# 6    $7,213.00   $7,176.94          $1.09         3.02%

# %%
print(dividend[['Stock Name', 'Symbol', 'Dividend/Share']])
# Out:
#   Stock Name Symbol Dividend/Share
# 0      Apple   AAPL          $2.28
# 8   Qualcomm   QCOM          $2.12
# 1  Microsoft   MSFT          $1.56
# 7      Cisco   CSCO          $1.16
# 6      Intel   INTC          $1.09

# %% [markdown]
# 1. C)Atribut Stock Name dan Symbol yang memiliki Market Value 5 tertinggi

# %%
database2 = df.sort_values(by='Market Value', ascending=False)
Market_Value = database2.head(5)
print(Market_Value[['Stock Name', 'Symbol', 'Market Value']])
# Out:
#                     Stock Name Symbol Market Value
# 5                     Alphabet   GOOG   $83,336.00
# 4   Hewlett Packard Enterprise    HPE    $8,842.50
# 10                      Redhat    RHT    $8,626.00
# 7                        Cisco   CSCO    $7,478.78
# 12                     Twitter   TWTR    $7,302.55

# %% [markdown]
# 1. D  Atribut Stock Name dan Symbol yang memiliki Annual Yield 7 tertinggi

# %%
database3 = df.sort_values(by='Annual Yield ', ascending=False)
Annual_Yield = database3.head(7)
print(Annual_Yield[['Stock Name', 'Symbol', 'Annual Yield ']])
# Out:
#                    Stock Name Symbol Annual Yield
# 8                    Qualcomm   QCOM         3.75%
# 7                       Cisco   CSCO         3.49%
# 6                       Intel   INTC         3.02%
# 1                   Microsoft   MSFT         2.38%
# 0                       Apple   AAPL         1.58%
# 4  Hewlett Packard Enterprise    HPE         1.47%
# 3                      Oracle   ORCL         1.44%
